# %%
function norm(x_m, var, x)
    return 1/sqrt(var*2*pi)*exp(-0.5*(x-x_m)^2/var)
end
# Out:
# norm (generic function with 1 method)

# %%
using PyPlot
 x = collect(-2:0.1:5)
plot(x, norm.(1, 0.3, x)+0.5 .*norm.(2.0, 0.8, x))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fd2c9ee8390>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fd2c9a18ef0>

# %%
norm.(1, 0.3, 1)
# Out:
# UndefVarError: e not defined
#
# Stacktrace:
#  [1] norm(::Int64, ::Float64, ::Int64) at ./In[9]:2
#  [2] _broadcast_getindex_evalf at ./broadcast.jl:574 [inlined]
#  [3] _broadcast_getindex at ./broadcast.jl:547 [inlined]
#  [4] getindex at ./broadcast.jl:507 [inlined]
#  [5] copy at ./broadcast.jl:734 [inlined]
#  [6] materialize(::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{0},Nothing,typeof(norm),Tuple{Int64,Float64,Int64}}) at ./broadcast.jl:724
#  [7] top-level scope at In[11]:1

# %%
exp
# Out:
# exp (generic function with 13 methods)
